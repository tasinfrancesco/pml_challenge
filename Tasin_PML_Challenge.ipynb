# %% [markdown]
# <a href="https://colab.research.google.com/github/tasinfrancesco/pml_challenge/blob/main/Tasin_PML_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import strptime
df = pd.read_csv("train.csv")

# %%
# print(df.describe())
print(df.head(5))
# dt = pd.read_csv("test.csv")
# print(dt[["UTC" not in cd for cd in dt["creation_date"]]])
type(df["creation_date"][0])
print(strptime(df["creation_date"][0], "%Y-%m-%d %H:%M:%S.%f %Z"))

print(strptime(df["creation_date"][1], "%Y-%m-%d %H:%M:%S.%f %Z"))
print(df["creation_date"][0])
print(df["creation_date"][1])

def timeinfo(timestr):
  time_struct = strptime(df["creation_date"][0], "%Y-%m-%d %H:%M:%S.%f %Z")

  #is it a weekend
  if time_struct.tm_wday >= 5:
    weekend = 1
  else:
    weekend = 0

  #is it a vacation
# Out:
#           id                                               text  \
# 0  107584783  Sincerely appreciate your taking a look. I nev...
# 1   47249018  That's not what I'm doing right now ?\nThe Map...
# 2   86118519  `/include/ssp/stdio.h` check the contents of t...
# 3   31185267  "At each step you multiply the value of the fi...
# 4  108802839  Everyone suggesting STRING_SPLIT, how can this...
#
#                  creation_date   post_id  user_id  score  target
# 0   2020-03-23 04:13:10.16 UTC  60795744  2811980      0       0
# 1  2015-04-09 20:51:55.367 UTC  29546664  4706994      0       0
# 2   2018-03-29 12:06:16.29 UTC  49555428  6451573      0       0
# 3   2013-12-27 13:07:06.67 UTC  20794579  2340452      0       0
# 4  2020-04-29 16:52:34.867 UTC  54926996  3319620      7       1
# time.struct_time(tm_year=2020, tm_mon=3, tm_mday=23, tm_hour=4, tm_min=13, tm_sec=10, tm_wday=0, tm_yday=83, tm_isdst=0)
# time.struct_time(tm_year=2015, tm_mon=4, tm_mday=9, tm_hour=20, tm_min=51, tm_sec=55, tm_wday=3, tm_yday=99, tm_isdst=0)
# 2020-03-23 04:13:10.16 UTC
# 2015-04-09 20:51:55.367 UTC

# %% [markdown]
# Ideas for feature engineering:
# - local comment frequency (estimated from change in post_id over time window)
# - is it a vacation
# - is it a weekend
#
# post
# - post length
# - positivity of content?
# - politeness?
#
# User ID?
# - is it better to predict for a given user (average) or for single posts?
#
#
# text vectorisation:
#
# analysis:
# - logistic regression (not great given collinearity)
# - random trees?
#
# predict score, then guess target (not target directly)
